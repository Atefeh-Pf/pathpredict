# %%
# Data Quelle: https://www.diw.de/de/diw_01.c.603154.de/soep_in_der_lehre.html#c_diw_01.c.603164.de

import pandas as pd

df = pd.read_stata('practice_dataset_eng.dta')

# Interaktive Ansicht
df.head(20)  # Erste 20 Zeilen
# Out:
#          id   syear         sex  alter  anz_pers  anz_kind bildung  \
# 0     194.0  2015.0  [1] female   59.0       2.0       0.0    10.5
# 1     194.0  2016.0  [1] female   60.0       2.0       0.0    10.5
# 2     194.0  2017.0  [1] female   61.0       2.0       0.0    10.5
# 3     194.0  2018.0  [1] female   62.0       2.0       0.0    10.5
# 4     194.0  2019.0  [1] female   63.0       2.0       0.0    10.5
# 5   19052.0  2015.0  [1] female   74.0       2.0       0.0    10.0
# 6   27495.0  2016.0  [1] female   35.0       3.0       1.0    15.0
# 7   27495.0  2018.0  [1] female   37.0       3.0       1.0    15.0
# 8   27495.0  2019.0  [1] female   38.0       3.0       1.0    15.0
# 9   22539.0  2015.0    [0] male   85.0       2.0       0.0    18.0
# 10  13224.0  2015.0  [1] female   73.0       1.0       0.0    10.5
# 11  13224.0  2016.0  [1] female   74.0       1.0       0.0    10.5
# 12  17316.0  2015.0    [0] male   43.0       4.0       2.0    15.0
# ...

# %%
# Beschreibende Statistik
df.describe()
# Out:
#                  id         syear         alter      anz_pers      anz_kind
# count  23522.000000  23522.000000  23522.000000  23445.000000  23445.000000
# mean   15943.962891   2016.837769     48.282204      2.906718      0.748262
# std     9143.335938      1.407175     18.332251      1.494616      1.110248
# min        4.000000   2015.000000     17.000000      1.000000      0.000000
# 25%     8100.000000   2016.000000     34.000000      2.000000      0.000000
# 50%    15982.000000   2017.000000     48.000000      2.000000      0.000000
# 75%    23834.250000   2018.000000     62.000000      4.000000      1.000000
# max    31773.000000   2019.000000    102.000000     13.000000     10.000000

# %%
# Datensatz-Struktur
df.shape  # Anzahl Zeilen, Spalten
# Out:
# (23522, 15)
